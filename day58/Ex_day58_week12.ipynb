# %%
def even_avg(number):
  even_number=[]
  for num in number:
      if num%2==0:
          even_number.append(num)
  if len(even_number)==0:

      return "no even number"
  average=sum(even_number)/len(even_number)
  return average

nums=[1,2,3,4,5,6,7,8,11,12,14,15]

print(even_avg(nums))
# Out:
# 7.666666666666667

# %%
import numpy as np
arr=np.random.randint(1,101,(5,5))
max_arr=np.max(arr,axis=1)
print(f"{max_arr}")
avg_arr=np.mean(arr)
print(f" avg_arr:{avg_arr}")
arr[arr<avg_arr]=0
print(arr)
# Out:
# [95 84 88 77 86]
#  avg_arr:48.76
# [[ 0 62 95  0  0]
#  [ 0  0 59 65 84]
#  [ 0  0  0  0 88]
#  [51 77  0  0  0]
#  [82 86 72  0 77]]

# %%
import pandas as pd
df=pd.DataFrame(
    {  "name": ["Ali", "Sara", "Reza", "Mina"],
    "age": [25, 30, 22, 28],
    "salary": [500, 800, 450, 900]}
)

df["tax"]=df["salary"]*0.10

high_salary=df[df["salary"]>600]
print(high_salary)

average_age=df["age"].mean()
print(average_age)

sorted_df=df.sort_values(by="salary",ascending=False)
print(sorted_df)
# Out:
#    name  age  salary   tax
# 1  Sara   30     800  80.0
# 3  Mina   28     900  90.0
# 26.25
#    name  age  salary   tax
# 3  Mina   28     900  90.0
# 1  Sara   30     800  80.0
# 0   Ali   25     500  50.0
# 2  Reza   22     450  45.0

# %%
import matplotlib.pyplot as plt
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
study_hours = [2, 3, 5, 4, 6, 7, 3]

plt.plot(days,study_hours)
plt.title("daily study hour")
plt.xlabel("days")
plt.ylabel("study_hours")
plt.grid(True)
plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

iris=load_iris()
x=iris.data
y=iris.target

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

model=KNeighborsClassifier(n_neighbors=3)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

acc=accuracy_score(y_test,y_pred)
print(acc)

new_sample = [[5.1, 3.5, 1.4, 0.2]]

prediction=model.predict(new_sample)
print("Prediction class:", prediction[0])
print("Prediction name:", iris.target_names[prediction[0]])
# Out:
# 1.0
# Prediction class: 0
# Prediction name: setosa
