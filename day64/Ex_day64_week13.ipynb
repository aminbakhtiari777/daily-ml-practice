# %%
import tensorflow as tf
from tensorflow.keras import layers, models


(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()


x_train = x_train / 255.0
x_test = x_test / 255.0


print("x_train:", x_train.shape)
print("y_train:", y_train.shape)
print("x_test:", x_test.shape)
print("y_test:", y_test.shape)


model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(10, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)


history = model.fit(
    x_train,
    y_train,
    epochs=5,
    validation_split=0.2
)
import numpy as np

index = 10

plt.imshow(x_test[index], cmap="gray")
plt.axis("off")
plt.show()

prediction = model.predict(x_test[index].reshape(1, 28, 28))

predicted_label = np.argmax(prediction)

print("Real label:", y_test[index])
print("Predicted label:", predicted_label)
# Out:
# x_train: (60000, 28, 28)
# y_train: (60000,)
# x_test: (10000, 28, 28)
# y_test: (10000,)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9219 - loss: 0.2672 - val_accuracy: 0.9578 - val_loss: 0.1427
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9659 - loss: 0.1118 - val_accuracy: 0.9662 - val_loss: 0.1113
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9758 - loss: 0.0783 - val_accuracy: 0.9723 - val_loss: 0.0958
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9809 - loss: 0.0591 - val_accuracy: 0.9707 - val_loss: 0.0996
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9854 - loss: 0.0453 - val_accuracy: 0.9687 - val_loss: 0.1074
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Real label: 0
# Predicted label: 0
